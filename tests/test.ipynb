# %% [markdown]
# # 1. Test Notebook
# *try the different functionalities implemented*

# %%
import sys
import os
import laspy
from semantic_segmentation_benchmark.metrics import Metrics

# %%
pc_ground_truth = laspy.read(r"D:\Raphael\filecration\temp_laz\1.copc.laz")
pc_predictions = laspy.read(r"D:\Raphael\filecration\temp_laz\2.copc.laz")

remap_ground_truth = {"default": 0, 2: 2, 18: 2, 31: 2, 3: 3, 4: 3, 5: 3, 6: 6, 21: 21, 22: 22, 26: 26}
remap_predictions = {"default": "keep", 29:0}

predictions, ground_truth = Metrics.get_matching_indices(pc_predictions, pc_ground_truth, precision=3)

Metrics.generate_report(predictions, ground_truth, remap_ground_truth=remap_ground_truth, remap_predictions=remap_predictions)
